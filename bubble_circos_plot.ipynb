# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import pycircos
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import argparse
import re,sys,os,math,gc
#plot module
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
plt.rcParams.update({'figure.max_open_warning': 100})
plt.style.use('seaborn-colorblind')
mpl.rcParams['ytick.direction'] = 'out'

#可P
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42

plt.clf()
Garc    = pycircos.Garc
Gcircle = pycircos.Gcircle

circle = Gcircle() 
df=pd.read_table('/annoroad/B_TET-074/D0_circos.txt',sep='\t')
#df['Number'] = np.log2(df['Number'])
df['end']=df['Number']
for i in range(len(df)):
    name   = df['Cell Type'][i]
    length = df['end'][i]
    arc    = Garc(arc_id=name, size=length, interspace=2, raxis_range=(550,600),facecolor=df['color'][i],edgecolor=df['color'][i], labelposition=100, label_visible=True)
    circle.add_garc(arc) 
circle.set_garcs(0,360)
values_all   = [] 
#arcdata_dict = collections.defaultdict(dict)
line=pd.read_table('/annoroad/B_TET-074/D0.connect.xls',sep='\t')
line=line[line['LR']>10]
line=line.reset_index(drop=True)
line=line.reset_index(drop=True)
for i in range(len(line)):
    name1  = line['cell_from'][i]     
    start1 = line['start_from'][i]
    end1   = line['end_from'][i]
    name2  = line['cell_to'][i]     
    start2 = line['start_to'][i]
    end2   = line['end_to'][i]
    source = (name1, start1, end1, 550)
    destination = (name2, start2, end2, 550)
    circle.chord_plot(source, destination, facecolor=line['color'][i],alpha=0.2)
#plt.savefig('D0.circos.pdf')
#circle.figure

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import pycircos
import matplotlib.pyplot as plt
plt.clf()
Garc    = pycircos.Garc
Gcircle = pycircos.Gcircle

circle = Gcircle() 
df=pd.read_table('/annoroad/B_TET-074/D7_circos.txt',sep='\t')
#df['Number'] = np.log2(df['Number'])
df['end']=df['Number']
for i in range(len(df)):
    name   = df['Cell Type'][i]
    length = df['end'][i]
    arc    = Garc(arc_id=name, size=length, interspace=2, raxis_range=(550,600),facecolor=df['color'][i],edgecolor=df['color'][i], labelposition=100, label_visible=True)
    circle.add_garc(arc) 
circle.set_garcs(0,360)
values_all   = [] 
#arcdata_dict = collections.defaultdict(dict)
line=pd.read_table('/annoroad/B_TET-074/D7.connect.xls',sep='\t')
line=line[line['LR']>10]
line=line.reset_index(drop=True)
line=line.reset_index(drop=True)
for i in range(len(line)):
    name1  = line['cell_from'][i]     
    start1 = line['start_from'][i]
    end1   = line['end_from'][i]
    name2  = line['cell_to'][i]     
    start2 = line['start_to'][i]
    end2   = line['end_to'][i]
    source = (name1, start1, end1, 550)
    destination = (name2, start2, end2, 550)
    circle.chord_plot(source, destination, facecolor=line['color'][i],alpha=0.2)
plt.savefig('D7.circos.pdf')
#circle.figure

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import pycircos
import matplotlib.pyplot as plt
plt.clf()
Garc    = pycircos.Garc
Gcircle = pycircos.Gcircle

circle = Gcircle() 
df=pd.read_table('/annoroad/B_TET-074/D14_circos.txt',sep='\t')
#df['Number'] = np.log2(df['Number'])
df['end']=df['Number']
for i in range(len(df)):
    name   = df['Cell Type'][i]
    length = df['end'][i]
    arc    = Garc(arc_id=name, size=length, interspace=2, raxis_range=(550,600),facecolor=df['color'][i],edgecolor=df['color'][i], labelposition=100, label_visible=True)
    circle.add_garc(arc) 
circle.set_garcs(0,360)
values_all   = [] 
#arcdata_dict = collections.defaultdict(dict)
line=pd.read_table('/annoroad/B_TET-074/D14.connect.xls',sep='\t')
line=line[line['LR']>10]
line=line.reset_index(drop=True)
line=line.reset_index(drop=True)
for i in range(len(line)):
    name1  = line['cell_from'][i]     
    start1 = line['start_from'][i]
    end1   = line['end_from'][i]
    name2  = line['cell_to'][i]     
    start2 = line['start_to'][i]
    end2   = line['end_to'][i]
    source = (name1, start1, end1, 550)
    destination = (name2, start2, end2, 550)
    circle.chord_plot(source, destination, facecolor=line['color'][i],alpha=0.2)
plt.savefig('D14.circos.pdf')
#circle.figure

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import pycircos
import matplotlib.pyplot as plt
plt.clf()
Garc    = pycircos.Garc
Gcircle = pycircos.Gcircle

circle = Gcircle() 
df=pd.read_table('/annoroad/B_TET-074/D21_circos.txt',sep='\t')
#df['Number'] = np.log2(df['Number'])
df['end']=df['Number']
for i in range(len(df)):
    name   = df['Cell Type'][i]
    length = df['end'][i]
    arc    = Garc(arc_id=name, size=length, interspace=2, raxis_range=(550,600),facecolor=df['color'][i],edgecolor=df['color'][i], labelposition=100, label_visible=True)
    circle.add_garc(arc) 
circle.set_garcs(0,360)
values_all   = [] 
#arcdata_dict = collections.defaultdict(dict)
line=pd.read_table('/annoroad/B_TET-074/D21.connect.xls',sep='\t')
line=line[line['LR']>10]
line=line.reset_index(drop=True)
line=line.reset_index(drop=True)
for i in range(len(line)):
    name1  = line['cell_from'][i]     
    start1 = line['start_from'][i]
    end1   = line['end_from'][i]
    name2  = line['cell_to'][i]     
    start2 = line['start_to'][i]
    end2   = line['end_to'][i]
    source = (name1, start1, end1, 550)
    destination = (name2, start2, end2, 550)
    circle.chord_plot(source, destination, facecolor=line['color'][i],alpha=0.2)
plt.savefig('D21.circos.pdf')
#circle.figure

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import textwrap
#from gapminder import gapminder # import data set 
line=pd.read_table('/Users/yuezhao/Downloads/cell_proportion.xls',sep='\t')
line['cell']=line['cell_from']+'-'+line['cell_to']+' '+line['sample']
line['gene']=line['ligand']+'-'+line['receptor']
line['cell_prop']=(line['ligand_prop']*line['receptor_prop'])**0.5
#x=['Ccl5-Ccr1','Ccl5-Ccr5','Ccl3-Ccr1','Ccl2-Ccr2','Ccl4-Ccr5','Spp1-Cd44','Spp1-Itgb1','Spp1-Itgav','Fn1-Cd44','Fn1-Itgb1','Fn1-Itgav','Cxcl2-Cxcr2','Ccl3-Ccr1','Il1b-Il1rap']
file=open('/Users/yuezhao/ligand-receptor-order-0411.txt')

x=[]
for i in file:
    i=i.strip()
    x.append(i)
x=['Spp1-Cd44',
 'Spp1-Itgb1',
 'Spp1-Itgb1',
 'Fn1-Cd44',
 'Fn1-Itgb1',
 'Fn1-Itgav',
 'Cxcl2-Cxcr2',
 'Ccl2-Ccr2',
 'Ccl4-Ccr5',
 'Ccl3-Ccr1',
 'Il1b-Il1rap',
 'Ccl5-Ccr1',
 'Ccl5-Ccr5']
ys=['Mac-Mac' ,'Mac-Neu' ,'Mac-T.NKT', 'Neu-Mac' ,'T.NKT-Mac']
yi=['D0','D7','D14','D21']

y=[]
for i in ys:
    for j in yi:
        cell=i+' '+j
        y.append(cell)

y.reverse()        

#line['LR']=np.log2(line['LR']+1)
line['cell_prop']=line['cell_prop']*100
size=[]
huey=[]
xp=[]
yp=[]
a=0
for i in y:
    l=line[line['cell']==i]
    b=0
    huex=[]
    for j in x:
        ls=l[l['gene']==j]
        ls=ls.reset_index(drop=True)
        if len(ls)>0:
            size.append(ls['cell_prop'][0])
            huex.append(ls['LR'][0])
        else:
            size.append(0)
            huex.append(0)
        b+=1
        xp.append(b)
        yp.append(a)
    huey.append(huex)
    a+=1
    

from scipy import stats
huey=stats.zscore(huey, axis=0, ddof=0)
hue=[]
for i in huey:
    for j in i:
        hue.append(j)

y=['Mac D0',
 'D7',
 'D14',
 'D21',
 'Neu D0',
 'D7',
 'D14',
 'D21',
 'T.NKT D0',
 'D7',
 'D14',
 'D21',
 'Mac D0',
 'D7',
 'D14',
 'D21',
 'Mac D0',
 'D7',
 'D14',
 'D21']
y.reverse()
# data 
fig=plt.figure(figsize=(6,5))
axes = fig.add_axes([0.2,0.2,0.6,0.6])

scatter=axes.scatter(x=xp, y=yp, s=size,c=hue, alpha=1,cmap='RdBu_r')
axes.spines['bottom'].set_linewidth(1)
axes.spines['left'].set_linewidth(1)
axes.spines['right'].set_linewidth(0)
axes.spines['top'].set_linewidth(0)
axes.tick_params(top=False,right=False,width=1,colors='black',direction='out')
axes.legend()
#x=[textwrap.fill(t.get_text(), 10)  for t in axes.get_xticklabels()]
axes.set_xticks(np.arange(len(x))+1)
axes.set_xticklabels(x,rotation=90)
axes.set_yticks(np.arange(len(y))+0)
axes.set_yticklabels(y,rotation=0)
#legend1 = axes.legend(*scatter.legend_elements(num=7),
                    #loc="upper right", title="LR",frameon=False,bbox_to_anchor=(1.25, 1.1))
#axes.add_artist(legend1)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
def colorbar(ax,im,vmin,vmax):
    axins1 = inset_axes(ax, width=0.1,height=0.6,loc=2, bbox_to_anchor=(-0.8, 0, 0.5, 1), bbox_transform=ax.transAxes,borderpad=0)
    cbar=plt.colorbar(im, cax=axins1, orientation='vertical',ticks=[vmin,vmax])
    axins1.tick_params(left='off',right='on',top='off',bottom='off',labelsize=10)
    axins1.yaxis.set_ticks_position('right')
    return cbar
ax2 = fig.add_axes([1,0,0.6,0.6])
cax=ax2.matshow(huey, cmap='RdBu_r')
vmin=huey.min()
vmax=huey.max()
cbar=colorbar(ax2,cax,vmin,vmax)
cbar.ax.set_title('LR', rotation=0,fontsize=10)
# Produce a legend for the price (sizes). Because we want to show the prices
# in dollars, we use the *func* argument to supply the inverse of the function
# used to calculate the sizes from above. The *fmt* ensures to show the price
# in dollars. Note how we target at 5 elements here, but obtain only 4 in the
# created legend due to the automatic round prices that are chosen for us.
kw = dict(prop="sizes", num=5, color='black', fmt="{x:.2f}",func=lambda s: (s/100))
legend2 = axes.legend(*scatter.legend_elements(**kw),loc="lower right", title="cell proportion",frameon=False,bbox_to_anchor=(1.35, 0.0))

# show the graph
plt.savefig('bubble.pdf')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x
# Out:
# ['Spp1-Cd44',
#  'Spp1-Itgb1',
#  'Spp1-Itgb1',
#  'Fn1-Cd44',
#  'Fn1-Itgb1',
#  'Fn-Itgav',
#  'Cxcl2-Cxcr2',
#  'Ccl2-Ccr2',
#  'Ccl4-Ccr5',
#  'Ccl3-Ccr1',
#  'Il-1b-Il1rap',
#  'Ccl5-Ccr1',
#  'Ccl5-Ccr5']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import textwrap
import argparse
import re,sys,os,math,gc
import numpy as np
import pandas as pd
import matplotlib as mpl
import copy
import math
from math import pi
mpl.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from scipy import sparse
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import copy
import math
import seaborn as sns
#from iced import normalization
from scipy.interpolate import BSpline, make_interp_spline

plt.rcParams.update({'figure.max_open_warning': 100000})
plt.style.use('seaborn-colorblind')
mpl.rcParams['ytick.direction'] = 'out'

mpl.rcParams['savefig.dpi'] = 300 #图片像素
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['pdf.fonttype']=42
#from gapminder import gapminder # import data set 
line=pd.read_table('/Users/yuezhao/Downloads/cell_proportion.xls',sep='\t')
line['cell']=line['cell_from']+'-'+line['cell_to']+' '+line['sample']
line['gene']=line['ligand']+'-'+line['receptor']
line['cell_prop']=(line['ligand_prop']*line['receptor_prop'])**0.5
x=['Ccl5-Ccr1','Ccl5-Ccr5','Ccl3-Ccr1','Ccl2-Ccr2','Ccl4-Ccr5','Spp1-Cd44','Spp1-Itgb1','Spp1-Itgav','Fn1-Cd44','Fn1-Itgb1','Fn1-Itgav','Cxcl2-Cxcr2','Ccl3-Ccr1','Il1b-Il1rap']
ys=['Mac-Mac' ,'Mac-Neu' ,'Mac-T.NKT', 'Neu-Mac' ,'T.NKT-Mac']
yi=['D0','D7','D14','D21']

y=[]
for i in ys:
    for j in yi:
        cell=i+' '+j
        y.append(cell)

y.reverse()        

#line['LR']=np.log2(line['LR']+1)
line['cell_prop']=line['cell_prop']*100
size=[]
huey=[]
xp=[]
yp=[]
a=0
for i in y:
    l=line[line['cell']==i]
    b=0
    huex=[]
    for j in x:
        ls=l[l['gene']==j]
        ls=ls.reset_index(drop=True)
        if len(ls)>0:
            size.append(ls['cell_prop'][0])
            huex.append(ls['LR'][0])
        else:
            size.append(0)
            huex.append(0)
        b+=1
        xp.append(b)
        yp.append(a)
    huey.append(huex)
    a+=1
    

from scipy import stats
huey=stats.zscore(huey, axis=0, ddof=0)
hue=[]
for i in huey:
    for j in i:
        hue.append(j)

y=['Mac D0',
 'D7',
 'D14',
 'D21',
 'Neu D0',
 'D7',
 'D14',
 'D21',
 'T.NKT D0',
 'D7',
 'D14',
 'D21',
 'Mac D0',
 'D7',
 'D14',
 'D21',
 'Mac D0',
 'D7',
 'D14',
 'D21']
y.reverse()
# data 
fig=plt.figure(figsize=(6,5))
axes = fig.add_axes([0.2,0.2,0.6,0.6])
my_colors=['#5A1216','#C02C38','#EE3F4D','#F07C82','#F1FB00','#2AFFBD','#0000A4']
colormap = mpl.colors.LinearSegmentedColormap.from_list('cmap',my_colors[::-1],500)
scatter=axes.scatter(x=xp, y=yp, s=size,c=hue, alpha=1,cmap=colormap)
axes.spines['bottom'].set_linewidth(1)
axes.spines['left'].set_linewidth(1)
axes.spines['right'].set_linewidth(0)
axes.spines['top'].set_linewidth(0)
axes.tick_params(top=False,right=False,width=1,colors='black',direction='out')
axes.legend()
#x=[textwrap.fill(t.get_text(), 10)  for t in axes.get_xticklabels()]
axes.set_xticks(np.arange(len(x))+1)
axes.set_xticklabels(x,rotation=90)
axes.set_yticks(np.arange(len(y))+0)
axes.set_yticklabels(y,rotation=0)
#legend1 = axes.legend(*scatter.legend_elements(num=7),
                    #loc="upper right", title="LR",frameon=False,bbox_to_anchor=(1.25, 1.1))
#axes.add_artist(legend1)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
def colorbar(ax,im,vmin,vmax):
    axins1 = inset_axes(ax, width=0.1,height=0.6,loc=2, bbox_to_anchor=(-0.8, 0, 0.5, 1), bbox_transform=ax.transAxes,borderpad=0)
    cbar=plt.colorbar(im, cax=axins1, orientation='vertical',ticks=[vmin,vmax])
    axins1.tick_params(left='off',right='on',top='off',bottom='off',labelsize=10)
    axins1.yaxis.set_ticks_position('right')
    return cbar
ax2 = fig.add_axes([1,0,0.6,0.6])
cax=ax2.matshow(huey, cmap=colormap)
vmin=huey.min()
vmax=huey.max()
cbar=colorbar(ax2,cax,vmin,vmax)
cbar.ax.set_title('LR', rotation=0,fontsize=10)
# Produce a legend for the price (sizes). Because we want to show the prices
# in dollars, we use the *func* argument to supply the inverse of the function
# used to calculate the sizes from above. The *fmt* ensures to show the price
# in dollars. Note how we target at 5 elements here, but obtain only 4 in the
# created legend due to the automatic round prices that are chosen for us.
kw = dict(prop="sizes", num=5, color='black', fmt="{x:.2f}",func=lambda s: (s/100))
legend2 = axes.legend(*scatter.legend_elements(**kw),loc="lower right", title="cell proportion",frameon=False,bbox_to_anchor=(1.35, 0.0))

# show the graph
plt.savefig('bubble2.pdf')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
lists=[]
for i in x:
    l=line[line['gene']==i]
    print (i,len(l))
    lists.append(l)
line=pd.concat(lists)
lists=[]
for i in y:
    l=line[line['cell']==i]
    print (i,len(l))
    lists.append(l)
# Out:
# Ccl5-Ccr1 90
# Ccl5-Ccr5 62
# Ccl3-Ccr1 86
# Ccl2-Ccr2 56
# Ccl4-Ccr5 63
# Spp1-Cd44 81
# Spp1-Itgb1 78
# Spp1-Itgav 46
# Fn1-Cd44 77
# Fn1-Itgb1 62
# Fn1-Itgav 26
# Cxcl2-Cxcr2 37
# Ccl3-Ccr1 86
# Il1b-Il1rap 44
# Mac-Mac D0 5
# Mac-Mac D7 7
# Mac-Mac D14 9
# Mac-Mac D21 7
# Mac-Neu D0 9
# Mac-Neu D7 5
# Mac-Neu D14 11
# Mac-Neu D21 8
# Mac-T.NKT D0 5
# Mac-T.NKT D7 8
# Mac-T.NKT D14 9
# Mac-T.NKT D21 11
# Neu-Mac D0 6
# Neu-Mac D7 8
# Neu-Mac D14 10
# Neu-Mac D21 6
# T.NKT-Mac D0 2
# T.NKT-Mac D7 8
# T.NKT-Mac D14 8
# T.NKT-Mac D21 8

# %%
y
# Out:
# ['Mac-Mac D0',
#  'Mac-Mac D7',
#  'Mac-Mac D14',
#  'Mac-Mac D21',
#  'Mac-Neu D0',
#  'Mac-Neu D7',
#  'Mac-Neu D14',
#  'Mac-Neu D21',
#  'Mac-T.NKT D0',
#  'Mac-T.NKT D7',
#  'Mac-T.NKT D14',
#  'Mac-T.NKT D21',
#  'Neu-Mac D0',
#  'Neu-Mac D7',
#  'Neu-Mac D14',
#  'Neu-Mac D21',
#  'T.NKT-Mac D0',
#  'T.NKT-Mac D7',
#  'T.NKT-Mac D14',
#  'T.NKT-Mac D21']

# %%
lists=[]
for i in y:
    l=line[line['cell']==i]
    for j in x:
        ls=l[l['gene']==j]
        if len(ls)==2:
            print (ls)
# Out:
#             cell       gene    ligand  receptor
# 3298  Mac-Mac D7  Ccl3-Ccr1  1.906128 -4.267772
# 3298  Mac-Mac D7  Ccl3-Ccr1  1.906128 -4.267772
#             cell       gene    ligand  receptor
# 3298  Mac-Mac D7  Ccl3-Ccr1  1.906128 -4.267772
# 3298  Mac-Mac D7  Ccl3-Ccr1  1.906128 -4.267772
#              cell       gene   ligand  receptor
# 6346  Mac-Mac D14  Ccl3-Ccr1  0.72336 -2.887525
# 6346  Mac-Mac D14  Ccl3-Ccr1  0.72336 -2.887525
#              cell       gene   ligand  receptor
# 6346  Mac-Mac D14  Ccl3-Ccr1  0.72336 -2.887525
# 6346  Mac-Mac D14  Ccl3-Ccr1  0.72336 -2.887525
#              cell       gene    ligand  receptor
# 9705  Mac-Mac D21  Ccl3-Ccr1 -0.679973  1.089194
# 9705  Mac-Mac D21  Ccl3-Ccr1 -0.679973  1.089194
#              cell       gene    ligand  receptor
# 9705  Mac-Mac D21  Ccl3-Ccr1 -0.679973  1.089194
# 9705  Mac-Mac D21  Ccl3-Ccr1 -0.679973  1.089194
#           cell       gene    ligand  receptor
# ...
